# %% [markdown]
# BIDIRECTIONAL LSTM

# %%
model31=Sequential()
model31.add(Embedding(vocabulary,100,input_length=max_len))
model31.add(Bidirectional(LSTM(300)))
model31.add(Dropout(0.3))
model31.add(Dense(64,activation='relu')) 
model31.add(Dense(9,activation='sigmoid'))
model31.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model31.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, 500, 100)          46770400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 600)               962400
# _________________________________________________________________
# dropout (Dropout)            (None, 600)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                38464
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 585
# ...
# Total params: 47,771,849
# Trainable params: 47,771,849
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)  
mc=ModelCheckpoint('best_BiLSTM_model.h31', monitor='val_loss', mode='min', save_best_only=True,verbose=1)

history31 = model31.fit(np.array(x_tr),np.array(y_tr),batch_size=100,epochs=100,validation_data=(np.array(x_val),np.array(y_val)),verbose=1,callbacks=[es,mc])
# Out:
# Epoch 1/100
# 375/375 [==============================] - ETA: 0s - loss: 0.2024 - accuracy: 0.6192
# Epoch 00001: val_loss improved from inf to 0.10848, saving model to best_BiLSTM_model.h31
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: best_BiLSTM_model.h31/assets
# ...

# %%
from keras.models import load_model
model= load_model('best_BiLSTM_model.h31')


from sklearn.metrics import classification_report

y_pred=model.predict_classes(np.array(x_val))
y_true = np.argmax(y_val, axis=1)
print(classification_report(y_true,y_pred))
# Out:
# WARNING:tensorflow:From <ipython-input-21-6f3e306a0ebe>:7: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       868
#            1       0.90      0.84      0.87      1408
#            2       0.99      0.98      0.98      1364
#            3       0.84      0.81      0.82       389
#            4       0.80      0.76      0.78      2425
#            5       0.84      0.90      0.87      5241
#            6       0.89      0.84      0.87      1556
# ...

# %% [markdown]
# BI-DIRECTIONAL GRU

# %%
model33=Sequential()
model33.add(Embedding(vocabulary,100,input_length=max_len))
model33.add(Bidirectional(LSTM(100)))
model33.add(Dropout(0.3))
model33.add(Dense(64,activation='relu')) 
model33.add(Dense(9,activation='softmax'))
model33.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model33.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 500, 100)          46770400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 200)               160800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                12864
# _________________________________________________________________
# dense_5 (Dense)              (None, 9)                 585
# ...
# Total params: 46,944,649
# Trainable params: 46,944,649
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)  
mc=ModelCheckpoint('best_model_bidirectionalGRU.h33', monitor='val_loss', mode='min', save_best_only=True,verbose=1)

# %%
history33 = model33.fit(np.array(x_tr),np.array(y_tr),batch_size=1200,epochs=100,validation_data=(np.array(x_val),np.array(y_val)),verbose=1,callbacks=[es,mc])
# Out:
# Epoch 1/100
# 32/32 [==============================] - ETA: 0s - loss: 1.9187 - accuracy: 0.3411
# Epoch 00001: val_loss improved from inf to 1.46183, saving model to best_model_bidirectionalGRU.h33
# INFO:tensorflow:Assets written to: best_model_bidirectionalGRU.h33/assets
# 32/32 [==============================] - 44s 1s/step - loss: 1.9187 - accuracy: 0.3411 - val_loss: 1.4618 - val_accuracy: 0.4404
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 1.1931 - accuracy: 0.5785
# Epoch 00002: val_loss improved from 1.46183 to 0.94258, saving model to best_model_bidirectionalGRU.h33
# INFO:tensorflow:Assets written to: best_model_bidirectionalGRU.h33/assets
# 32/32 [==============================] - 43s 1s/step - loss: 1.1931 - accuracy: 0.5785 - val_loss: 0.9426 - val_accuracy: 0.6470
# Epoch 3/100
# 32/32 [==============================] - ETA: 0s - loss: 0.7097 - accuracy: 0.7637
# ...

# %%
from keras.models import load_model
model= load_model('best_model_bidirectionalGRU.h33')


from sklearn.metrics import classification_report

y_pred=model.predict_classes(np.array(x_val))
y_true = np.argmax(y_val, axis=1)
print(classification_report(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       868
#            1       0.89      0.87      0.88      1408
#            2       0.97      0.97      0.97      1364
#            3       0.89      0.80      0.84       389
#            4       0.77      0.86      0.82      2425
#            5       0.90      0.85      0.87      5241
#            6       0.83      0.88      0.85      1556
#            7       0.92      0.93      0.92      2257
#            8       1.00      0.98      0.99       527
#
#     accuracy                           0.89     16035
#    macro avg       0.91      0.90      0.90     16035
# weighted avg       0.89      0.89      0.89     16035
